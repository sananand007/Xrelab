# %%
import os
import face_recognition
from PIL import Image
print(os.getcwd())
for i in range(1, 41):
    images=[]
    for j in range(1,7):
        path_="/notebooks/orl_faces/s"+str(i)+"/"+ str(j) + ".pgm"
        images.append(face_recognition.load_image_file(path_))
        name="s"+str(i)+"img"+str(j)+".png"
        img=Image.fromarray(images[j-1])
        path_to_save="/notebooks/faceaugm/input/"+name
        img.save(path_to_save)
    #path_to_input="input/"+str(i) +".pgm"
# Out:
# /notebooks/faceaugm

# %%
# %run  demo.py "input/s10img1.png"
# %run  demo.py "input/s10img2.png"
# %run  demo.py "input/s10img3.png"
# %run  demo.py "input/s10img4.png"
# %run  demo.py "input/s10img5.png"
# %run  demo.py "input/s10img6.png"
# %run  demo.py "input/s11img1.png"
# %run  demo.py "input/s11img2.png"
# %run  demo.py "input/s11img3.png"
# %run  demo.py "input/s11img4.png"
# %run  demo.py "input/s11img5.png"
# %run  demo.py "input/s11img6.png"
# %run  demo.py "input/s12img1.png"
# %run  demo.py "input/s12img2.png"
# %run  demo.py "input/s12img3.png"
# %run  demo.py "input/s12img4.png"
# %run  demo.py "input/s12img5.png"
# %run  demo.py "input/s12img6.png"
# %run  demo.py "input/s13img1.png"
# %run  demo.py "input/s13img2.png"
# %run  demo.py "input/s13img3.png"
# %run  demo.py "input/s13img4.png"
# %run  demo.py "input/s13img5.png"
# %run  demo.py "input/s13img6.png"
# %run  demo.py "input/s14img1.png"
# %run  demo.py "input/s14img2.png"
# %run  demo.py "input/s14img3.png"
# %run  demo.py "input/s14img4.png"
# %run  demo.py "input/s14img5.png"
# %run  demo.py "input/s14img6.png"
# %run  demo.py "input/s15img1.png"
# %run  demo.py "input/s15img2.png"
# %run  demo.py "input/s15img3.png"
# %run  demo.py "input/s15img4.png"
# %run  demo.py "input/s15img5.png"
# %run  demo.py "input/s15img6.png"
# %run  demo.py "input/s16img1.png"
# %run  demo.py "input/s16img2.png"
# %run  demo.py "input/s16img3.png"
# %run  demo.py "input/s16img4.png"
# %run  demo.py "input/s16img5.png"
# %run  demo.py "input/s16img6.png"
# %run  demo.py "input/s17img1.png"
# %run  demo.py "input/s17img2.png"
# %run  demo.py "input/s17img3.png"
# %run  demo.py "input/s17img4.png"
# %run  demo.py "input/s17img5.png"
# %run  demo.py "input/s17img6.png"
# %run  demo.py "input/s18img1.png"
# %run  demo.py "input/s18img2.png"
# %run  demo.py "input/s18img3.png"
# %run  demo.py "input/s18img4.png"
# %run  demo.py "input/s18img5.png"
# %run  demo.py "input/s18img6.png"
# %run  demo.py "input/s19img1.png"
# %run  demo.py "input/s19img2.png"
# %run  demo.py "input/s19img3.png"
# %run  demo.py "input/s19img4.png"
# %run  demo.py "input/s19img5.png"
# %run  demo.py "input/s19img6.png"
# %run  demo.py "input/s1img1.png"
# %run  demo.py "input/s1img2.png"
# %run  demo.py "input/s1img3.png"
# %run  demo.py "input/s1img4.png"
# %run  demo.py "input/s6img4.png"
# %run  demo.py "input/s6img5.png"
# %run  demo.py "input/s6img6.png"
# %run  demo.py "input/s7img1.png"
# %run  demo.py "input/s7img2.png"
# %run  demo.py "input/s7img3.png"
# %run  demo.py "input/s7img4.png"
# %run  demo.py "input/s7img5.png"
# %run  demo.py "input/s7img6.png"
# %run  demo.py "input/s8img1.png"
# %run  demo.py "input/s8img2.png"
# %run  demo.py "input/s8img3.png"
# %run  demo.py "input/s8img4.png"
# %run  demo.py "input/s8img5.png"
# %run  demo.py "input/s8img6.png"
# %run  demo.py "input/s9img1.png"
# %run  demo.py "input/s9img2.png"
# %run  demo.py "input/s9img3.png"
# %run  demo.py "input/s9img4.png"
# %run  demo.py "input/s9img5.png"
# %run  demo.py "input/s9img6.png"
# Out:
# ['s10img1,input/s10img1.png,None'] output/
# > Preloading all the models for efficiency
# > Loading pose model in model3D_aug_-00_00_01.mat
# > Loading pose model in model3D_aug_-00_00_02.mat
# > Loading pose model in model3D_aug_-00_00_03.mat
# > Loading pose model in model3D_aug_-00_00_04.mat
# > Loading pose model in model3D_aug_-00_00_05.mat
# > Loading pose model in model3D_aug_-00_00_06.mat
# > Loading pose model in model3D_aug_-00_00_07.mat
# > Loading pose model in model3D_aug_-00_00_08.mat
# > Loading pose model in model3D_aug_-00_00_09.mat
# > Loading pose model in model3D_aug_-00_00_10.mat
# > Loading pose model in model3D_aug_-22_00_01.mat
# > Loading pose model in model3D_aug_-22_00_02.mat
# > Loading pose model in model3D_aug_-22_00_03.mat
# > Loading pose model in model3D_aug_-22_00_04.mat
# > Loading pose model in model3D_aug_-22_00_05.mat
# > Loading pose model in model3D_aug_-22_00_06.mat
# > Loading pose model in model3D_aug_-22_00_07.mat
# ...

# %% [markdown]
# ### Overview
# The goal of this homework assignment is to help you develop a complete face recognition system that embraces the most recent technical advancements.
# In this module and previous modules, you have learn the following computer vision and machine learning techniques
# + Histogram of intensities/colors
# + Histogram of oriented gradients (HOG)
# + LM filter bank
# + Local Binary Pattern (LBP)
# + Bag of words
# + K-nearest Neighbor (KNN)
# + Softmax classifier
# + Feedforward Neural Network
# + Convolutional Neural Network (CNNs)
# + Domain specific data augmentation

# %%
#form the training images

import os
import glob
import PIL
import scipy.misc
from pathlib import Path
import numpy as np
import cv2

output_path="/notebooks/faceaugm/output/"
X_train=[]
width,height=28,28 # resize to apply the NN, as per the directions
for i in range(1,41):
    temp="s"+str(i)
    blip=[]
    for i in range(1,7):
        name=temp+"img"+str(i)
        final_path=output_path+name
        temp_=[]
        if os.path.exists(final_path):
            for f in Path(final_path).glob('*.jpg'):
                img=scipy.misc.imread(f)[:,:,-1]
                img_resize=scipy.misc.imresize(img, [width,height])
                temp_.append(img_resize)
            if temp_: blip.extend(np.asarray(temp_))    
    X_train.append(np.asarray(blip))
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:23: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:24: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
## Veerify once the images are extracted
for i in range(0,7):
    print("Image shape of some of the images", X_train[0].shape)
    im=Image.fromarray(X_train[0][i])
    #name="test_image_"+str(i)+".png"
    #im.save(name)
# Out:
# Image shape of some of the images (190, 28, 28)
# Image shape of some of the images (190, 28, 28)
# Image shape of some of the images (190, 28, 28)
# Image shape of some of the images (190, 28, 28)
# Image shape of some of the images (190, 28, 28)
# Image shape of some of the images (190, 28, 28)
# Image shape of some of the images (190, 28, 28)

# %% [markdown]
# ### Problem-1
#
# #### Problem 2  (Orl dataset and use of Data-augmentation and CNN to classify images)
#
# + The objective of this problem is to develop a program that can identify facial photos.
# + The folder “orl_faces” includes facial photos of 40 subjects, each with 10 photos.
# + We will be using Data augmentation to generate more synthesized images of the training set to use for training,
# which will be a step ahead from problem-1
# + There is a difference we are not using LBP or HOG for extracting any feature maps, but we will be just trying
# out end to end image classification

# %% [markdown]
# ## Step-1

# %%
# Load all the images
path=os.getcwd()
folder="/notebooks/orl_faces/"
images=[]
for i in range(1,41):
    val="s"+str(i)
    final_path=folder+val
    temp=[]
    for f in Path(final_path).glob('*.pgm'):
        img=scipy.misc.imread(f)
        img_resize=scipy.misc.imresize(img, [width,height])
        temp.append(img_resize)
    images.append(np.asarray(temp))
# Out:
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   # Remove the CWD from sys.path while we load stuff.
# /opt/conda/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## Step-2

# %%
def train_test_split(Images):
    train=[]
    test=[]
    #print(len(Images[39]))
    for i in range(40):
        temp_train=[Images[i][j] for j in range(6)]
        temp_test=[Images[i][j] for j in range(6,10)]
        train.append(np.asarray(temp_train))
        test.append(np.asarray(temp_test))
    return np.asarray(train), np.asarray(test)

X_train_org, X_test = train_test_split(images)

# %%
print(X_train_org.shape)
print(X_test.shape)
# Out:
# (40, 6, 28, 28)
# (40, 4, 28, 28)

# %%
fin_array=[]
for i in range(40):
    max_val=X_train[i].shape[0]
    new_array=[]
    for j in range(max_val):
        new_array.append(X_train[i][j])
    new_array.extend(X_train_org[i][:])
    fin_array.append(np.asarray(new_array))

# %%
fin_array=np.asarray(fin_array)

# %%
X_train_=fin_array
X_test_=X_test

# %%
print(X_train_.shape, X_test_.shape)
# Out:
# (40,) (40, 4, 28, 28)

# %%
print("Training set dimentions")
for i in range(40):
    print(X_train_[i].shape)
# Out:
# Training set dimentions
# (196, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (286, 28, 28)
# (286, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (286, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (266, 28, 28)
# (306, 28, 28)
# (286, 28, 28)
# (266, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (306, 28, 28)
# (156, 28, 28)
# (306, 28, 28)
# (166, 28, 28)
# (306, 28, 28)
# (156, 28, 28)
# (306, 28, 28)
# (246, 28, 28)
# (286, 28, 28)

# %% [markdown]
# ## Step-3
# + Each subject has different number of images present, so we have to deal with that
# + Based on the number of images we will have a different 1st dimension
# + This is too tough to train if the 1st dimensions do not match so I will just take the lower 1st dimension and use that
#     + Lowest # of augmented images = 156 (I will use that)
# + There is an issue with the demo.py script as it is not able to recocognize some of the images and hence for certain subjects for certain images we do not see the augmented images generated

# %%
def convert(X_):
    X_train_temp=[]
    for i in range(40):
        X_train_temp.append(X_train_[i][:156])
    return np.asarray(X_train_temp)
X_train=convert(X_train_)

# %%
print(X_train.shape)
# Out:
# (40, 156, 28, 28)

# %%
# One hot encode the labels as well for the train and test
def labels_train(X_):
    train_lab=[]
    for i in range(40):
        temp_=[0]*40
        temp_[i]=1
        temp_tr=[]
        for j in range(X_[i].shape[0]):
            temp_tr.append(temp_)
        train_lab.append(np.asarray(temp_tr))
    return np.asarray(train_lab)

y_train=labels_train(X_train)


def labels_test():
    test_lab =[]
    for i in range(40): #i is the subject so based on that you will one hot encode
        temp_=[0]*40
        temp_[i]=1
        temp_tst=[]
        for j in range(10):
            if j<=5:
                pass
            else: 
                temp_tst.append(temp_)
        test_lab.append(temp_tst)
    return np.asarray(test_lab)

y_test = labels_test()

# %%
print("Training labels shape: {}, test labels shape: {}".format(y_train.shape, y_test.shape))
# Out:
# Training labels shape: (40, 156, 40), test labels shape: (40, 4, 40)

# %%
## Using the Softmax Classifier with Tensorflow
import tensorflow as tf
print("TensorFlow version " + tf.__version__)
tf.set_random_seed(0)
# Out:
# TensorFlow version 1.9.0

# %%
# Reshaping the Training set and test set to use with TF
reshaped_train_set = np.reshape(X_train, (6240, X_train.shape[2],X_train.shape[3]))
reshaped_train_set = reshaped_train_set.reshape(-1, 784)
reshaped_test_set = np.reshape(X_test_, (160, X_test_.shape[2], X_test_.shape[3]))
reshaped_test_set = reshaped_test_set.reshape(-1, 784)
print("Reshaped Train set shape {}, Reshaped Test set shape {}".format(reshaped_train_set.shape, reshaped_test_set.shape))

# Reshaping the Labels
reshaped_train_labels  = np.reshape(y_train, (6240, y_train.shape[-1]))
reshaped_test_labels   = np.reshape(y_test, (160, y_test.shape[-1]))
print("Reshaped Train labels shape {}, Reshaped Test labels shape {}".format(reshaped_train_labels.shape, reshaped_test_labels.shape))

# Normalize the feature data before training
maximum_tr=max(reshaped_train_set[0])
reshaped_train_set_norm = reshaped_train_set/(1.0*maximum_tr)
maximum_test=max(reshaped_test_set[0])
reshaped_test_set_norm = reshaped_test_set/(1.0*maximum_test)
# Out:
# Reshaped Train set shape (6240, 784), Reshaped Test set shape (160, 784)
# Reshaped Train labels shape (6240, 40), Reshaped Test labels shape (160, 40)

# %%
'''Trains and evaluates a fully-connected neural net classifier'''
import time
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
## Using the Softmax Classifier with Tensorflow
import tensorflow as tf
print("TensorFlow version " + tf.__version__)
tf.set_random_seed(0)
beginTime = time.time()

# Parameter definitions
batch_size = 10
learning_rate = 0.0003
hidden_units=120
max_steps = 2000

# Define input placeholders for images and labels
x = tf.placeholder(tf.float32, shape=[None, 784])
y_ = tf.placeholder(tf.float32, shape=[None, 40])

## TODO : Just plain 2 L FNN only

'''
Wieght Initialization
'''
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)


'''
Convolution and Pooling
'''
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
# Out:
# TensorFlow version 1.9.0

# %%
# size = [filter_size, filter_size, input_channel, number_of_output_channels]
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x, [-1, 28, 28, 1])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([3, 3, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 40])
b_fc2 = bias_variable([40])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %%
# Train
import time
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

beginTime = time.time()

cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
confusion_matrix = tf.confusion_matrix(tf.argmax(y_,1), tf.argmax(y_conv,1))

max_steps = 5000
batch_size=10

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    # Repeat max_steps times
    for i in range(max_steps):
        # Generate input data batch
        indices = np.random.choice(reshaped_train_set_norm.shape[0], batch_size)
        images_batch = reshaped_train_set_norm[indices]
        labels_batch = reshaped_train_labels[indices]

        # Periodically print out the model's current accuracy
        if i % 100 == 0:
            train_accuracy = accuracy.eval(feed_dict={x: images_batch, y_: labels_batch, keep_prob: 1.0})
            #train_accuracy = sess.run(accuracy, feed_dict={images_placeholder: images_batch, labels_placeholder: labels_batch})
            print('Step {:5d}: training accuracy {:g}'.format(i, train_accuracy))

        # Perform a single training step
        sess.run(train_step, feed_dict={x: images_batch,y_: labels_batch, keep_prob: 0.5})
    # After finishing the training, evaluate on the test set
    test_accuracy, conf_mat = sess.run([accuracy, confusion_matrix], feed_dict={x: reshaped_test_set_norm,y_: reshaped_test_labels, keep_prob: 1.0})
    print('Test accuracy {:g}'.format(test_accuracy))
    print('Confusion Matrix',conf_mat)
endTime = time.time()
print('Total time: {:5.2f}s'.format(endTime - beginTime))
# Out:
# Step     0: training accuracy 0
# Step   100: training accuracy 0.1
# Step   200: training accuracy 0.4
# Step   300: training accuracy 0.1
# Step   400: training accuracy 0.8
# Step   500: training accuracy 0.8
# Step   600: training accuracy 0.9
# Step   700: training accuracy 0.8
# Step   800: training accuracy 0.8
# Step   900: training accuracy 0.8
# Step  1000: training accuracy 0.8
# Step  1100: training accuracy 1
# Step  1200: training accuracy 1
# Step  1300: training accuracy 1
# Step  1400: training accuracy 1
# Step  1500: training accuracy 0.9
# Step  1600: training accuracy 1
# Step  1700: training accuracy 1
# Step  1800: training accuracy 1
# Step  1900: training accuracy 1
# Step  2000: training accuracy 1
# Step  2100: training accuracy 1
# Step  2200: training accuracy 1
# Step  2300: training accuracy 1
# Step  2400: training accuracy 1
# Step  2500: training accuracy 1
# Step  2600: training accuracy 1
# Step  2700: training accuracy 1
# ...

# %%
# Making sense of the confusion matrix
for idx,c in enumerate(conf_mat[:]):
    if idx!=np.argmax(c, 0):
        print("Wrong Prediction for class : {}".format(idx))
# Out:
# Wrong Prediction for class : 0
# Wrong Prediction for class : 1
# Wrong Prediction for class : 2
# Wrong Prediction for class : 3
# Wrong Prediction for class : 5
# Wrong Prediction for class : 7
# Wrong Prediction for class : 8
# Wrong Prediction for class : 9
# Wrong Prediction for class : 10
# Wrong Prediction for class : 11
# Wrong Prediction for class : 12
# Wrong Prediction for class : 13
# Wrong Prediction for class : 14
# Wrong Prediction for class : 15
# Wrong Prediction for class : 16
# Wrong Prediction for class : 17
# Wrong Prediction for class : 18
# Wrong Prediction for class : 19
# Wrong Prediction for class : 20
# Wrong Prediction for class : 22
# Wrong Prediction for class : 23
# Wrong Prediction for class : 24
# Wrong Prediction for class : 25
# Wrong Prediction for class : 26
# Wrong Prediction for class : 29
# Wrong Prediction for class : 30
# Wrong Prediction for class : 34
# Wrong Prediction for class : 35
# Wrong Prediction for class : 37
# ...

# %% [markdown]
# ### Results for CNN
#
# + Training accuracy reaches 100%
# + Test accuracy reaches almost ~30%, which is better than using LBP with CNN
# + Performance is not very good here, probably Data augmentation is not helping here, it is making things worse
